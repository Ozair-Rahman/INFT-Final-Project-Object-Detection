# %%
import numpy as np  # linear algebra
import cv2 # opencv
import matplotlib.pyplot as plt # image plotting
# keras
from keras import Sequential
from keras.layers import Flatten, Dense
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "./Face Mask Dataset/Train"
test_dir = "./Face Mask Dataset/Test"
val_dir = "./Face Mask Dataset/Validation"

# %%
import os

# folder path
dir_path = r'./Face Mask Dataset/Test/WithMask'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 483

# %%
# Read a sample image
img = cv2.imread("./face-mask-detection/images/maksssksksss352.png")
img = cv2.imread("./test2.jpg")


# Keep a copy of coloured image
orig_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)  # colored output image

# Convert image to grayscale
img = cv2.cvtColor(img, cv2.IMREAD_GRAYSCALE)

# loading haarcascade_frontalface_default.xml
face_detection_model = cv2.CascadeClassifier("./haar-cascades-for-face-detection/haarcascade_frontalface_default.xml")

# detect faces in the given image
return_faces = face_detection_model.detectMultiScale(
    img, scaleFactor=1.08, minNeighbors=4
)  # returns a list of (x,y,w,h) tuples

# plotting the returned values
for (x, y, w, h) in return_faces:
    cv2.rectangle(orig_img, (x, y), (x + w, y + h), (0, 0, 255), 1)

plt.figure(figsize=(12, 12))
plt.imshow(orig_img)  # display the image

# %%
# Data preprocessing
# Train data
#CNN Algorithm
datagenerator = ImageDataGenerator(
    rescale=1.0 / 255, horizontal_flip=True, zoom_range=0.2, shear_range=0.2
)
train_generator = datagenerator.flow_from_directory(
    directory=train_dir, target_size=(128, 128), class_mode="categorical", batch_size=32
)

# Validation data
val_generator = datagenerator.flow_from_directory(
    directory=val_dir, target_size=(128, 128), class_mode="categorical", batch_size=32
)

# Test data
test_generator = datagenerator.flow_from_directory(
    directory=val_dir, target_size=(128, 128), class_mode="categorical", batch_size=32
)
# Out:
# Found 10000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Initializing the VGG19 model
vgg19_model = VGG19(weights="imagenet", include_top=False, input_shape=(128, 128, 3))

for layer in vgg19_model.layers:
    layer.trainable = False

# Initialize a sequential model
model = Sequential()
model.add(vgg19_model)
model.add(Flatten())
model.add(Dense(2, activation="sigmoid"))
model.summary()

# Compiling the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics="accuracy")
# Out:
# 2023-04-12 13:41:35.760732: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-12 13:41:35.761041: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2)                 16386
#
# =================================================================
# Total params: 20,040,770
# Trainable params: 16,386
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Fit the model on train data along with validation data
model_history = model.fit_generator(
    generator=train_generator,
    steps_per_epoch=len(train_generator) // 32,
    epochs=20,
    validation_data=val_generator,
    validation_steps=len(val_generator) // 32,
)
# Out:
# /home/caleb/anaconda3/envs/keras/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/20
# 9/9 [==============================] - 23s 2s/step - loss: 0.6445 - accuracy: 0.6597
# Epoch 2/20
# 9/9 [==============================] - 20s 2s/step - loss: 0.3346 - accuracy: 0.8542
# Epoch 3/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.2104 - accuracy: 0.9097
# Epoch 4/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.1706 - accuracy: 0.9306
# Epoch 5/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.1100 - accuracy: 0.9688
# Epoch 6/20
# 9/9 [==============================] - 20s 2s/step - loss: 0.1092 - accuracy: 0.9688
# Epoch 7/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0844 - accuracy: 0.9861
# Epoch 8/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0654 - accuracy: 0.9896
# Epoch 9/20
# 9/9 [==============================] - 20s 2s/step - loss: 0.0993 - accuracy: 0.9792
# Epoch 10/20
# 9/9 [==============================] - 20s 2s/step - loss: 0.0629 - accuracy: 0.9861
# Epoch 11/20
# 9/9 [==============================] - 20s 2s/step - loss: 0.0976 - accuracy: 0.9653
# Epoch 12/20
# 9/9 [==============================] - 20s 2s/step - loss: 0.0885 - accuracy: 0.9757
# Epoch 13/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0736 - accuracy: 0.9792
# Epoch 14/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0774 - accuracy: 0.9653
# Epoch 15/20
# 9/9 [==============================] - 19s 2s/step - loss: 0.0838 - accuracy: 0.9706
# Epoch 16/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0871 - accuracy: 0.9688
# Epoch 17/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0571 - accuracy: 0.9861
# Epoch 18/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0512 - accuracy: 0.9861
# Epoch 19/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0572 - accuracy: 0.9826
# Epoch 20/20
# 9/9 [==============================] - 21s 2s/step - loss: 0.0583 - accuracy: 0.9861

# %%
# Evaluate model performance on test data Using CNN
model_loss, model_acc = model.evaluate(test_generator)
print("Model has a loss of %.2f and accuracy %.2f%%" % (model_loss, model_acc*100))
# Out:
# 25/25 [==============================] - 56s 2s/step - loss: 0.0652 - accuracy: 0.9775
# Model has a loss of 0.07 and accuracy 97.75%

# %%
model.save('data/saved_model.h5')

# %%
# label for mask detection
mask_det_label = {0: "Mask", 1: "No Mask"}
mask_det_label_colour = {0: (0, 255, 0), 1: (255, 0, 0)}
pad_y = 1  # padding for result text


main_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)  # colored output image

# For detected faces in the image
for i in range(len(return_faces)):
    (x, y, w, h) = return_faces[i]
    cropped_face = main_img[y : y + h, x : x + w]
    cropped_face = cv2.resize(cropped_face, (128, 128))
    cropped_face = np.reshape(cropped_face, [1, 128, 128, 3]) / 255.0
    mask_result = model.predict(cropped_face)  # make model prediction
    print_label = mask_det_label[mask_result.argmax()] # get mask/no mask based on prediction
    label_colour = mask_det_label_colour[mask_result.argmax()] # green for mask, red for no mask

    # Print result
    (t_w, t_h), _ = cv2.getTextSize(
        print_label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1
    )  # getting the text size

    cv2.rectangle(
        main_img,
        (x, y + pad_y),
        (x + t_w, y - t_h - pad_y - 6),
        label_colour,
        -1,
    )  # draw rectangle

    cv2.putText(
        main_img,
        print_label,
        (x, y - 6),
        cv2.FONT_HERSHEY_DUPLEX,
        0.4,
        (255, 255, 255), # white
        1,
    )  # print text

    cv2.rectangle(
        main_img,
        (x, y),
        (x + w, y + h),
        label_colour,
        1,
    )  # draw bounding box on face

plt.figure(figsize=(10, 10))
plt.imshow(main_img)  # display image
# Out:
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 193ms/step

# %% [markdown]
# ### Confusion Matrix

# %%
#Confusion Matrix and Classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

batch_size = 32

filenames = val_generator.filenames
nb_samples = len(filenames)

Y_pred = model.predict(val_generator, nb_samples // batch_size + 1)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(val_generator.classes, y_pred))

print('Classification Report')
target_names = ['Mask', 'No Mask']
print(classification_report(val_generator.classes, y_pred, target_names=target_names))
# Out:
# 25/25 [==============================] - 57s 2s/step
# Confusion Matrix
# [[197 203]
#  [195 205]]
# Classification Report
#               precision    recall  f1-score   support
#
#         Mask       0.50      0.49      0.50       400
#      No Mask       0.50      0.51      0.51       400
#
#     accuracy                           0.50       800
#    macro avg       0.50      0.50      0.50       800
# weighted avg       0.50      0.50      0.50       800

# %% [markdown]
# ### VGG19 Model Accuracy

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['loss'])
plt.title('VGG19 Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Loss'], loc='upper left')
plt.show()

# %% [markdown]
# ### InceptionV3 Model

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# Initializing the model
inception = InceptionV3(weights="imagenet", include_top=False, input_shape=(128, 128, 3))

for layer in inception.layers:
    layer.trainable = False

# Initialize a sequential model
model = Sequential()
model.add(inception)
model.add(Flatten())
model.add(Dense(2, activation="sigmoid"))
model.summary()

# Compiling the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics="accuracy")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2, 2, 2048)        21802784
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_1 (Dense)             (None, 2)                 16386
#
# =================================================================
# Total params: 21,819,170
# Trainable params: 16,386
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# Fit the model on train data along with validation data
model_history = model.fit_generator(
    generator=train_generator,
    steps_per_epoch=len(train_generator) // 32,
    epochs=20,
    validation_data=val_generator,
    validation_steps=len(val_generator) // 32,
)
# Out:
# /home/caleb/anaconda3/envs/keras/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/20
# 9/9 [==============================] - 11s 821ms/step - loss: 0.5499 - accuracy: 0.7569
# Epoch 2/20
# 9/9 [==============================] - 8s 830ms/step - loss: 0.0985 - accuracy: 0.9757
# Epoch 3/20
# 9/9 [==============================] - 8s 837ms/step - loss: 0.0696 - accuracy: 0.9826
# Epoch 4/20
# 9/9 [==============================] - 7s 809ms/step - loss: 0.0792 - accuracy: 0.9861
# Epoch 5/20
# 9/9 [==============================] - 8s 823ms/step - loss: 0.1573 - accuracy: 0.9826
# Epoch 6/20
# 9/9 [==============================] - 7s 807ms/step - loss: 0.1146 - accuracy: 0.9792
# Epoch 7/20
# 9/9 [==============================] - 7s 787ms/step - loss: 0.1628 - accuracy: 0.9757
# Epoch 8/20
# 9/9 [==============================] - 7s 807ms/step - loss: 0.0360 - accuracy: 0.9826
# Epoch 9/20
# 9/9 [==============================] - 7s 821ms/step - loss: 0.1237 - accuracy: 0.9757
# Epoch 10/20
# 9/9 [==============================] - 7s 818ms/step - loss: 0.0876 - accuracy: 0.9826
# Epoch 11/20
# 9/9 [==============================] - 7s 807ms/step - loss: 0.0705 - accuracy: 0.9861
# Epoch 12/20
# 9/9 [==============================] - 7s 784ms/step - loss: 0.0673 - accuracy: 0.9861
# Epoch 13/20
# 9/9 [==============================] - 7s 807ms/step - loss: 0.0471 - accuracy: 0.9792
# Epoch 14/20
# 9/9 [==============================] - 8s 855ms/step - loss: 0.0655 - accuracy: 0.9792
# Epoch 15/20
# 9/9 [==============================] - 7s 814ms/step - loss: 0.0684 - accuracy: 0.9826
# Epoch 16/20
# 9/9 [==============================] - 8s 830ms/step - loss: 0.0575 - accuracy: 0.9896
# Epoch 17/20
# 9/9 [==============================] - 7s 828ms/step - loss: 0.0857 - accuracy: 0.9861
# Epoch 18/20
# 9/9 [==============================] - 7s 803ms/step - loss: 0.0082 - accuracy: 0.9965
# Epoch 19/20
# 9/9 [==============================] - 7s 790ms/step - loss: 0.1109 - accuracy: 0.9792
# Epoch 20/20
# 9/9 [==============================] - 8s 836ms/step - loss: 0.1249 - accuracy: 0.9826

# %%
# Evaluate model performance on test data Using CNN
model_loss, model_acc = model.evaluate(test_generator)
print("Model has a loss of %.2f and accuracy %.2f%%" % (model_loss, model_acc*100))
# Out:
# 25/25 [==============================] - 21s 793ms/step - loss: 0.0348 - accuracy: 0.9925
# Model has a loss of 0.03 and accuracy 99.25%

# %%
model.save('data/inception_model.h5')

# %%
Y_pred = model.predict(val_generator, nb_samples // batch_size + 1)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(val_generator.classes, y_pred))

print('Classification Report')
target_names = ['Mask', 'No Mask']
print(classification_report(val_generator.classes, y_pred, target_names=target_names))
# Out:
# 25/25 [==============================] - 20s 758ms/step
# Confusion Matrix
# [[200 200]
#  [200 200]]
# Classification Report
#               precision    recall  f1-score   support
#
#         Mask       0.50      0.50      0.50       400
#      No Mask       0.50      0.50      0.50       400
#
#     accuracy                           0.50       800
#    macro avg       0.50      0.50      0.50       800
# weighted avg       0.50      0.50      0.50       800

# %% [markdown]
# ### InceptionV3 Model Accuracy

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['loss'])
plt.title('InceptionV3 Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Loss'], loc='upper left')
plt.show()

# %% [markdown]
# ### Hyper parameter tuning

# %%
import tensorflow as tf
from keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
import pandas as pd

model_history_list = []
results = []

# not enough resources for this
param_grid = {'batch_size': [16, 32, 64],
              'epochs': [10, 20, 30],
              'learning_rate': [0.001, 0.01, 0.1]}

# for batch_size in param_grid['batch_size']:
#     for epochs in param_grid['epochs']:
epochs = 20
batch_size = 32

# %%
for learning_rate in param_grid['learning_rate']:
    model = Sequential()
    model.add(inception)
    model.add(Flatten())
    model.add(Dense(2, activation="sigmoid"))
    
    # Compiling the model
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics="accuracy")

    model_history_list.append(model.fit_generator(
    generator=train_generator,
    steps_per_epoch=len(train_generator) // batch_size,
    epochs=epochs,
    validation_data=val_generator,
    validation_steps=len(val_generator) // batch_size,))

    model_loss, model_acc = model.evaluate(test_generator)

    # Append current results
    results.append({
        'Accuracy': model_acc,
        'Loss': model_loss,
        'Epochs': epochs,
        'Batch_Size': batch_size,
        'Learning_Rate': learning_rate
    })
# Out:
# Epoch 1/20
# /home/caleb/anaconda3/envs/keras/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   from ipykernel import kernelapp as app
# 9/9 [==============================] - 12s 851ms/step - loss: 1.7485 - accuracy: 0.6562
# Epoch 2/20
# 9/9 [==============================] - 8s 844ms/step - loss: 0.3141 - accuracy: 0.9618
# Epoch 3/20
# 9/9 [==============================] - 8s 825ms/step - loss: 0.0282 - accuracy: 0.9931
# Epoch 4/20
# 9/9 [==============================] - 8s 838ms/step - loss: 0.0648 - accuracy: 0.9757
# Epoch 5/20
# 9/9 [==============================] - 8s 865ms/step - loss: 0.1305 - accuracy: 0.9757
# Epoch 6/20
# 9/9 [==============================] - 8s 841ms/step - loss: 0.1271 - accuracy: 0.9792
# Epoch 7/20
# 9/9 [==============================] - 8s 827ms/step - loss: 0.0788 - accuracy: 0.9792
# Epoch 8/20
# 9/9 [==============================] - 7s 798ms/step - loss: 0.1047 - accuracy: 0.9896
# Epoch 9/20
# 9/9 [==============================] - 7s 794ms/step - loss: 0.2391 - accuracy: 0.9688
# Epoch 10/20
# 9/9 [==============================] - 8s 837ms/step - loss: 0.0978 - accuracy: 0.9896
# Epoch 11/20
# 9/9 [==============================] - 7s 807ms/step - loss: 0.0771 - accuracy: 0.9792
# Epoch 12/20
# 9/9 [==============================] - 7s 826ms/step - loss: 0.1096 - accuracy: 0.9896
# Epoch 13/20
# 9/9 [==============================] - 7s 804ms/step - loss: 0.0490 - accuracy: 0.9896
# Epoch 14/20
# 9/9 [==============================] - 7s 786ms/step - loss: 0.0767 - accuracy: 0.9861
# Epoch 15/20
# 9/9 [==============================] - 8s 821ms/step - loss: 0.0462 - accuracy: 0.9861
# Epoch 16/20
# 9/9 [==============================] - 7s 822ms/step - loss: 0.0731 - accuracy: 0.9792
# Epoch 17/20
# 9/9 [==============================] - 7s 805ms/step - loss: 0.0103 - accuracy: 0.9965
# Epoch 18/20
# 9/9 [==============================] - 7s 827ms/step - loss: 0.0410 - accuracy: 0.9931
# Epoch 19/20
# 9/9 [==============================] - 8s 835ms/step - loss: 0.0241 - accuracy: 0.9896
# Epoch 20/20
# 9/9 [==============================] - 8s 854ms/step - loss: 0.0442 - accuracy: 0.9861
# 25/25 [==============================] - 21s 775ms/step - loss: 0.0326 - accuracy: 0.9925
# Epoch 1/20
# 9/9 [==============================] - 12s 874ms/step - loss: 0.2880 - accuracy: 0.9097
# Epoch 2/20
# 9/9 [==============================] - 7s 813ms/step - loss: 0.0895 - accuracy: 0.9722
# Epoch 3/20
# 9/9 [==============================] - 7s 815ms/step - loss: 0.1586 - accuracy: 0.9792
# Epoch 4/20
# 9/9 [==============================] - 8s 827ms/step - loss: 0.1685 - accuracy: 0.9792
# Epoch 5/20
# 9/9 [==============================] - 7s 791ms/step - loss: 0.0309 - accuracy: 0.9896
# Epoch 6/20
# 9/9 [==============================] - 7s 766ms/step - loss: 0.0396 - accuracy: 0.9896
# Epoch 7/20
# 9/9 [==============================] - 8s 841ms/step - loss: 0.0981 - accuracy: 0.9722
# Epoch 8/20
# 9/9 [==============================] - 7s 802ms/step - loss: 0.0993 - accuracy: 0.9861
# Epoch 9/20
# 9/9 [==============================] - 7s 787ms/step - loss: 0.0201 - accuracy: 0.9896
# Epoch 10/20
# 9/9 [==============================] - 8s 820ms/step - loss: 0.0349 - accuracy: 0.9896
# Epoch 11/20
# 9/9 [==============================] - 7s 797ms/step - loss: 0.1008 - accuracy: 0.9861
# Epoch 12/20
# 9/9 [==============================] - 7s 787ms/step - loss: 0.1118 - accuracy: 0.9779
# Epoch 13/20
# 9/9 [==============================] - 7s 784ms/step - loss: 0.0984 - accuracy: 0.9757
# Epoch 14/20
# 9/9 [==============================] - 8s 839ms/step - loss: 0.0790 - accuracy: 0.9861
# Epoch 15/20
# 9/9 [==============================] - 7s 798ms/step - loss: 0.1386 - accuracy: 0.9826
# Epoch 16/20
# 9/9 [==============================] - 7s 808ms/step - loss: 0.0690 - accuracy: 0.9826
# Epoch 17/20
# 9/9 [==============================] - 7s 782ms/step - loss: 0.1970 - accuracy: 0.9722
# Epoch 18/20
# 9/9 [==============================] - 7s 811ms/step - loss: 0.1347 - accuracy: 0.9757
# Epoch 19/20
# 9/9 [==============================] - 7s 804ms/step - loss: 0.0395 - accuracy: 0.9861
# Epoch 20/20
# 9/9 [==============================] - 7s 769ms/step - loss: 0.1044 - accuracy: 0.9861
# 25/25 [==============================] - 21s 774ms/step - loss: 0.0825 - accuracy: 0.9787
# Epoch 1/20
# 9/9 [==============================] - 11s 820ms/step - loss: 0.7418 - accuracy: 0.8125
# Epoch 2/20
# 9/9 [==============================] - 7s 759ms/step - loss: 0.2345 - accuracy: 0.9444
# Epoch 3/20
# 9/9 [==============================] - 7s 775ms/step - loss: 0.1772 - accuracy: 0.9688
# Epoch 4/20
# 9/9 [==============================] - 7s 825ms/step - loss: 0.1427 - accuracy: 0.9583
# Epoch 5/20
# 9/9 [==============================] - 7s 800ms/step - loss: 0.0756 - accuracy: 0.9757
# Epoch 6/20
# 9/9 [==============================] - 7s 779ms/step - loss: 0.1179 - accuracy: 0.9826
# Epoch 7/20
# 9/9 [==============================] - 7s 757ms/step - loss: 0.1005 - accuracy: 0.9896
# Epoch 8/20
# 9/9 [==============================] - 7s 815ms/step - loss: 0.1162 - accuracy: 0.9861
# Epoch 9/20
# 9/9 [==============================] - 7s 797ms/step - loss: 0.0672 - accuracy: 0.9896
# Epoch 10/20
# 9/9 [==============================] - 7s 809ms/step - loss: 0.1055 - accuracy: 0.9896
# Epoch 11/20
# 9/9 [==============================] - 7s 786ms/step - loss: 0.0387 - accuracy: 0.9931
# Epoch 12/20
# 9/9 [==============================] - 7s 799ms/step - loss: 0.0323 - accuracy: 0.9861
# Epoch 13/20
# 9/9 [==============================] - 7s 769ms/step - loss: 0.1854 - accuracy: 0.9722
# Epoch 14/20
# 9/9 [==============================] - 7s 754ms/step - loss: 0.0195 - accuracy: 0.9890
# Epoch 15/20
# 9/9 [==============================] - 7s 803ms/step - loss: 0.0434 - accuracy: 0.9861
# Epoch 16/20
# 9/9 [==============================] - 7s 770ms/step - loss: 0.1042 - accuracy: 0.9792
# Epoch 17/20
# 9/9 [==============================] - 7s 780ms/step - loss: 0.0332 - accuracy: 0.9896
# Epoch 18/20
# 9/9 [==============================] - 7s 730ms/step - loss: 0.0401 - accuracy: 0.9853
# Epoch 19/20
# 9/9 [==============================] - 7s 762ms/step - loss: 0.1327 - accuracy: 0.9792
# Epoch 20/20
# 9/9 [==============================] - 7s 812ms/step - loss: 0.0654 - accuracy: 0.9896
# 25/25 [==============================] - 21s 788ms/step - loss: 0.0260 - accuracy: 0.9850

# %%
# Convert to Pandas DataFrame and sort descendingly by accuracy
results = pd.DataFrame(results)
results = results.sort_values(by='Accuracy', ascending=False)
results
# Out:
#    Accuracy      Loss  Epochs  Batch_Size  Learning_Rate
# 0   0.99250  0.032594      20          32          0.001
# 2   0.98500  0.026029      20          32          0.100
# 1   0.97875  0.082533      20          32          0.010

# %%
def plots():
    for i in range(len(model_history_list)):
        plt.plot(model_history_list[i].history['accuracy'])
        plt.plot(model_history_list[i].history['loss'])
        plt.title('InceptionV3 Model accuracy {}'.format(param_grid['learning_rate'][i]))
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Accuracy', 'Loss'], loc='upper left')
        plt.show()

# %%
plots()

# %% [markdown]
# #### The model with the smallest learning rate had the highest accuracy, but the learning rate of 0.1 was better than the learning rate of 0.01

# %% [markdown]
# ### Data Visualization

# %%
import ipyplot
mask = ['WithMask', 'WithoutMask']
n = 184
img = cv2.imread(f"./Face Mask Dataset/Test/{mask[1]}/{n}.png")

ipyplot.plot_images([f"./Face Mask Dataset/Test/{mask[1]}/{n}.png"], img_width=128)



main_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)  # colored output image


cropped_face = main_img
cropped_face = cv2.resize(cropped_face, (128, 128))
cropped_face = np.reshape(cropped_face, [1, 128, 128, 3]) / 255.0
mask_result = model.predict(cropped_face)  # make model prediction
print_label = mask_det_label[mask_result.argmax()]
print(print_label)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-kz9WmyEkpCdZJawBLx5C4Q {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kz9WmyEkpCdZJawBLx5C4Q {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kz9WmyEkpCdZJawBLx5C4Q {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kz9WmyEkpCdZJawBLx5C4Q:checked ~ #ipyplot-html-viewer-textarea-kz9WmyEkpCdZJawBLx5C4Q {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kz9WmyEkpCdZJawBLx5C4Q:checked + #ipyplot-html-viewer-label-kz9WmyEkpCdZJawBLx5C4Q:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-kz9WmyEkpCdZJawBLx5C4Q">
#         <label id="ipyplot-html-viewer-label-kz9WmyEkpCdZJawBLx5C4Q" for="ipyplot-html-viewer-toggle-kz9WmyEkpCdZJawBLx5C4Q">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-kz9WmyEkpCdZJawBLx5C4Q" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-C5sdSLqkycKN8ijk9bmAkr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-C5sdSLqkycKN8ijk9bmAkr {
#             width: 128px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr {
#             width: 128px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr img {
#             width: 128px;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-C5sdSLqkycKN8ijk9bmAkr">
#     <div class="ipyplot-placeholder-div-C5sdSLqkycKN8ijk9bmAkr">
#         <div id="ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr-iQ2eS3kRTe6Veo3eK4cpD7" class="ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Test/WithoutMask/184.png</h4><img src="Face Mask Dataset/Test/WithoutMask/184.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr-iQ2eS3kRTe6Veo3eK4cpD7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-C5sdSLqkycKN8ijk9bmAkr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-C5sdSLqkycKN8ijk9bmAkr {
#             width: 128px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr {
#             width: 128px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr img {
#             width: 128px;
#         }
#
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-C5sdSLqkycKN8ijk9bmAkr">
#     <div class="ipyplot-placeholder-div-C5sdSLqkycKN8ijk9bmAkr">
#         <div id="ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr-iQ2eS3kRTe6Veo3eK4cpD7" class="ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Test/WithoutMask/184.png</h4><img src="Face Mask Dataset/Test/WithoutMask/184.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-C5sdSLqkycKN8ijk9bmAkr-iQ2eS3kRTe6Veo3eK4cpD7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 1/1 [==============================] - 0s 257ms/step
# No Mask

# %%
! pip install ipyplot

# %%
import ipyplot

lst = ['4', '5', '7', '8', '9']

def sample():
    
    mask = ['WithMask', 'WithoutMask']
    for m in mask:
        print(f'\t\t----{m}----')
        for i in lst:

            image_files = []
            for i in lst:
                image_files.append(f'./Face Mask Dataset/Train/{m}/{i}.png')
        ipyplot.plot_images(image_files, img_width=128)

sample()
# Out:
# 		----WithMask----
#     <style>
#         #ipyplot-html-viewer-toggle-FRRwTFv6VA7zAytXasGf2L {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-FRRwTFv6VA7zAytXasGf2L {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-FRRwTFv6VA7zAytXasGf2L {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-FRRwTFv6VA7zAytXasGf2L:checked ~ #ipyplot-html-viewer-textarea-FRRwTFv6VA7zAytXasGf2L {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-FRRwTFv6VA7zAytXasGf2L:checked + #ipyplot-html-viewer-label-FRRwTFv6VA7zAytXasGf2L:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-FRRwTFv6VA7zAytXasGf2L">
#         <label id="ipyplot-html-viewer-label-FRRwTFv6VA7zAytXasGf2L" for="ipyplot-html-viewer-toggle-FRRwTFv6VA7zAytXasGf2L">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-FRRwTFv6VA7zAytXasGf2L" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-A2h4cD8Vybmoc6Q5UsRXEf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf {
#             width: 128px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf {
#             width: 128px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf img {
#             width: 128px;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-A2h4cD8Vybmoc6Q5UsRXEf">
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-QNT5ZHBY8vkxATYDY9kL6x" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/4.png</h4><img src="Face Mask Dataset/Train/WithMask/4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-QNT5ZHBY8vkxATYDY9kL6x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-FkEF5Nd5yLFsrGudJuBPrk" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/5.png</h4><img src="Face Mask Dataset/Train/WithMask/5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-FkEF5Nd5yLFsrGudJuBPrk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-crweKd8esRqYvJdoKsihwX" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/7.png</h4><img src="Face Mask Dataset/Train/WithMask/7.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-crweKd8esRqYvJdoKsihwX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-DwkqMWBigXDVUqUHpcESeT" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/8.png</h4><img src="Face Mask Dataset/Train/WithMask/8.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-DwkqMWBigXDVUqUHpcESeT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-WHdUrkykasKRd2Bo4oCc2Q" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/9.png</h4><img src="Face Mask Dataset/Train/WithMask/9.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-WHdUrkykasKRd2Bo4oCc2Q">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-A2h4cD8Vybmoc6Q5UsRXEf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf {
#             width: 128px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf {
#             width: 128px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf img {
#             width: 128px;
#         }
#
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-A2h4cD8Vybmoc6Q5UsRXEf">
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-QNT5ZHBY8vkxATYDY9kL6x" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/4.png</h4><img src="Face Mask Dataset/Train/WithMask/4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-QNT5ZHBY8vkxATYDY9kL6x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-FkEF5Nd5yLFsrGudJuBPrk" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/5.png</h4><img src="Face Mask Dataset/Train/WithMask/5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-FkEF5Nd5yLFsrGudJuBPrk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-crweKd8esRqYvJdoKsihwX" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/7.png</h4><img src="Face Mask Dataset/Train/WithMask/7.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-crweKd8esRqYvJdoKsihwX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-DwkqMWBigXDVUqUHpcESeT" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/8.png</h4><img src="Face Mask Dataset/Train/WithMask/8.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-DwkqMWBigXDVUqUHpcESeT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-A2h4cD8Vybmoc6Q5UsRXEf">
#         <div id="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-WHdUrkykasKRd2Bo4oCc2Q" class="ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithMask/9.png</h4><img src="Face Mask Dataset/Train/WithMask/9.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-A2h4cD8Vybmoc6Q5UsRXEf-WHdUrkykasKRd2Bo4oCc2Q">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 		----WithoutMask----
#     <style>
#         #ipyplot-html-viewer-toggle-jVYRLJ2Gi6A3hjdLwXKwbZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jVYRLJ2Gi6A3hjdLwXKwbZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jVYRLJ2Gi6A3hjdLwXKwbZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jVYRLJ2Gi6A3hjdLwXKwbZ:checked ~ #ipyplot-html-viewer-textarea-jVYRLJ2Gi6A3hjdLwXKwbZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jVYRLJ2Gi6A3hjdLwXKwbZ:checked + #ipyplot-html-viewer-label-jVYRLJ2Gi6A3hjdLwXKwbZ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jVYRLJ2Gi6A3hjdLwXKwbZ">
#         <label id="ipyplot-html-viewer-label-jVYRLJ2Gi6A3hjdLwXKwbZ" for="ipyplot-html-viewer-toggle-jVYRLJ2Gi6A3hjdLwXKwbZ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jVYRLJ2Gi6A3hjdLwXKwbZ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-aNj5u6BUGVSSsymnMjAjcQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ {
#             width: 128px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ {
#             width: 128px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ img {
#             width: 128px;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-aNj5u6BUGVSSsymnMjAjcQ">
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-M6687tXRp35fFJxhaaEkbD" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/4.png</h4><img src="Face Mask Dataset/Train/WithoutMask/4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-M6687tXRp35fFJxhaaEkbD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-bYNVpc7zwfrpwEgTqkud2o" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/5.png</h4><img src="Face Mask Dataset/Train/WithoutMask/5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-bYNVpc7zwfrpwEgTqkud2o">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-nJxeFQzRi43Z3hkSNyRhuX" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/7.png</h4><img src="Face Mask Dataset/Train/WithoutMask/7.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-nJxeFQzRi43Z3hkSNyRhuX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-KimEGYMawvQjBVLzX7ExHe" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/8.png</h4><img src="Face Mask Dataset/Train/WithoutMask/8.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-KimEGYMawvQjBVLzX7ExHe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-WidEV4X7xQCfN7HKr4qyWG" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/9.png</h4><img src="Face Mask Dataset/Train/WithoutMask/9.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-WidEV4X7xQCfN7HKr4qyWG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-aNj5u6BUGVSSsymnMjAjcQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ {
#             width: 128px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ {
#             width: 128px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ img {
#             width: 128px;
#         }
#
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-aNj5u6BUGVSSsymnMjAjcQ">
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-M6687tXRp35fFJxhaaEkbD" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/4.png</h4><img src="Face Mask Dataset/Train/WithoutMask/4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-M6687tXRp35fFJxhaaEkbD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-bYNVpc7zwfrpwEgTqkud2o" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/5.png</h4><img src="Face Mask Dataset/Train/WithoutMask/5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-bYNVpc7zwfrpwEgTqkud2o">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-nJxeFQzRi43Z3hkSNyRhuX" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/7.png</h4><img src="Face Mask Dataset/Train/WithoutMask/7.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-nJxeFQzRi43Z3hkSNyRhuX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-KimEGYMawvQjBVLzX7ExHe" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/8.png</h4><img src="Face Mask Dataset/Train/WithoutMask/8.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-KimEGYMawvQjBVLzX7ExHe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aNj5u6BUGVSSsymnMjAjcQ">
#         <div id="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-WidEV4X7xQCfN7HKr4qyWG" class="ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Face Mask Dataset/Train/WithoutMask/9.png</h4><img src="Face Mask Dataset/Train/WithoutMask/9.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aNj5u6BUGVSSsymnMjAjcQ-WidEV4X7xQCfN7HKr4qyWG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
